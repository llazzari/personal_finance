# %%
transactions: str = """......"""

# %%
import base64

# Decode the base64 content
pdf_bytes = base64.b64decode(transactions)

# Save the decoded content to a PDF file (optional)
# with open("bank_statement.pdf", "wb") as pdf_file:
    # pdf_file.write(pdf_bytes)

# %%
import io
import pdfplumber

def extract_text_from_pdf(pdf_bytes):
    text = ""
    with pdfplumber.open(io.BytesIO(pdf_bytes), password='4389') as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

pdf_text = extract_text_from_pdf(pdf_bytes)
print(pdf_text[:970])
# Out:
# Sistema de Conta Corrente Pág. 1
# REL. DE EXTRATO PERIÓDICO
# BANCO C6 S.A. ABERTO DR:01/10/2024 DP: 01/10/2024 15:12:35
# Data Inicial:01/05/2024
# Data Final: 30/09/2024
# Agência:0001 Conta:000028765669-1 Situação:LIBERADA Categoria de Conta: GARANTIDA Gerente:GERENTE GERAL
# NICKELI DA SILVA CHAVES 037.625.260-01
# RUA BARAO DE AZEVEDO MACHADO 21 BLOCO C, APTO 401
# PELOTAS RS 96020-150
# AGÊNCIA: 0001 CONTA CORRENTE: 000028765669-1 SITUAÇÃO: LIBERADA
# NICKELI DA SILVA CHAVES
# DATA DESCRIÇÃO DOC VALOR D/C VALOR
# 30/04/2024 SALDO DISPONIVEL INICIAL 2.798,48
# 30/04/2024 SALDO VINCULADO INICIAL 0,00
# 30/04/2024 SALDO BLOQUEADO INICIAL 0,00
# 02/05/2024 PIX RECEBIDO-NICKELI CHAVES PSICOLOGA LTDA 000000000000 5.000,00 C
# 02/05/2024 EMISSAO DE CDB 000000000000 2.000,00 D
# 02/05/2024 COMPRA DE ATIVO B3-Compra de Ações - BBSE3F 000000000000 342,43 D
# 02/05/2024 COMPRA DE ATIVO B3-Compra de Ações - BRAP3F 000000000000 189,08 D
# ...

# %%
from typing import Optional
from pydantic import BaseModel, Field

class Transaction(BaseModel):
    year: Optional[int] = Field(default=None, description="Year of the transaction")
    month: Optional[int] = Field(default=None, description="Month of the transaction")
    bank: Optional[str] = Field(default=None, description="Bank of the transaction")
    description: Optional[str] = Field(default=None, description="Description of the transaction")
    amount: Optional[float] = Field(default=None, description="Amount of the transaction")

class Transactions(BaseModel):
    transactions: list[Transaction]

# %%
import os
from langchain_mistralai import ChatMistralAI

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

MISTRAL_API_KEY = os.environ.get("MISTRAL_API_KEY")

if not MISTRAL_API_KEY:
    raise ValueError("Missing MISTRAL_API_KEY environment variable")

prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an assistant in charge of extracting information from a bank statement written in Portuguese. "
            "Only extract information about the following attributes: year, month, bank, description, amount. "
            "Each transaction will have a specific date and will be either an expense (D) or income (C), for expenses use a negative amount and for income use a positive amount."
            "Return a JSON object with the following structure: {example}. "
            "If you do not know the value of an attribute asked to extract, "
            "return null for the attribute's value.",
        ),
        # Please see the how-to about improving performance with
        # reference examples.
        # MessagesPlaceholder('examples'),
        ("human", "{transactions}"),
    ]
)
example = "[{'month': <month>, 'year': <year>, 'bank': <bank>, 'description': <description>, 'amount': <amount>}]"

llm = ChatMistralAI(name="pixtral-12b-2409", temperature=0)
# structured_llm = llm.with_structured_output(
#     schema=Transactions,
# )

prompt = prompt_template.invoke({"example": example, "transactions": pdf_text})

response = llm.invoke(prompt)

# %%
import json

content = response.content
if not type(content) is str:
    raise Exception("Content is not a JSON string.")

content = content.replace("BANCO C6 S.A.", "C6")
transactions_data = json.loads(content)
transactions = Transactions(transactions=transactions_data)
print(transactions)
# Out:
# transactions=[Transaction(year=2024, month=5, bank='C6', description='SALDO DISPONIVEL INICIAL', amount=-2798.48), Transaction(year=2024, month=5, bank='C6', description='PIX RECEBIDO-NICKELI CHAVES PSICOLOGA LTDA', amount=5000.0), Transaction(year=2024, month=5, bank='C6', description='EMISSAO DE CDB', amount=-2000.0), Transaction(year=2024, month=5, bank='C6', description='COMPRA DE ATIVO B3-Compra de Ações - BBSE3F', amount=-342.43), Transaction(year=2024, month=5, bank='C6', description='COMPRA DE ATIVO B3-Compra de Ações - BRAP3F', amount=-189.08), Transaction(year=2024, month=5, bank='C6', description='CREDITO OPERACAO B3-02/05/2024', amount=9.66), Transaction(year=2024, month=5, bank='C6', description='PLANO PLATINUM-Planos Átomos', amount=-40.0), Transaction(year=2024, month=5, bank='C6', description='PIX RECEBIDO-NILVA REGINA DA SILVA', amount=1275.0), Transaction(year=2024, month=5, bank='C6', description='TRANSF ENVIADA PIX', amount=-7.4), Transaction(year=2024, month=5, b
# ...
