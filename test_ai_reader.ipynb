# %%
from typing import Optional

from pydantic import BaseModel, Field


class Transaction(BaseModel):
    year: Optional[int] = Field(default=None, description="Year of the transaction")
    month: Optional[int] = Field(default=None, description="Month of the transaction")
    bank: Optional[str] = Field(default=None, description="Bank of the transaction")
    description: Optional[str] = Field(
        default=None, description="Description of the transaction"
    )
    amount: Optional[float] = Field(
        default=None, description="Amount of the transaction"
    )


class Transactions(BaseModel):
    transactions: list[Transaction]

# %%
import re
from pathlib import Path

inter = Path.cwd() / "database" / "inter.csv"
inter_content: str = re.sub(r"\s{2}+", "", inter.read_text().strip().lower())

total_lines = inter_content.count("\n")
half_size = total_lines // 2
first_half = "\n".join(inter_content.split("\n")[:half_size])
second_half = "\n".join(inter_content.split("\n")[half_size:])
total = [first_half, second_half]
print(f"Total lines: {total_lines}")
print(f"Lines in each half: {half_size}")
# Out:
# Total lines: 61
# Lines in each half: 30

# %%
import os

from langchain_core.prompts import ChatPromptTemplate
from langchain_mistralai import ChatMistralAI

MISTRAL_API_KEY = os.environ.get("MISTRAL_API_KEY")

if not MISTRAL_API_KEY:
    raise ValueError("Missing MISTRAL_API_KEY environment variable")

prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an assistant in charge of extracting information from a bank statement written in Portuguese. "
            "Only extract information about the following attributes: year, month, bank, description, amount. "
            "Each transaction will have a specific date and will be either an expense (D or a negative value) or income (C or a positive value). "
            "For expenses use a negative amount and for incomes use a positive amount. "
            "There will be a single bank per statement. "
            "Return a JSON object with the following structure: {example}. That is, a list of transactions, where each transaction is a dictionary with the attributes year, month, bank, description, and amount. "
            "If you do not know the value of an attribute asked to extract, "
            "return null for the attribute's value.",
        ),
        # Please see the how-to about improving performance with
        # reference examples.
        # MessagesPlaceholder('examples'),
        ("human", "{transactions}"),
    ]
)

llm = ChatMistralAI(name="mistral-large-latest", temperature=0)


def extract_transactions(llm, chunk: str) -> Transactions:
    output_example: str = "[{'month': <month>, 'year': <year>, 'bank': <bank>, 'description': <description>, 'amount': <amount>}]"

    prompt = prompt_template.invoke({"example": output_example, "transactions": chunk})

    response = llm.invoke(prompt)
    return response.content

# %%
formatted_batches = [extract_transactions(llm, content) for content in total]
formatted_batches
# Out:
# ['[\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * juros s/capital 38 bbas3",\n"amount": 5.70\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * dividendos 30 petr4",\n"amount": 46.55\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * dividendos 30 petr4",\n"amount": 15.79\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado nicki samuel da silva chaves",\n"amount": -16.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado silvia regina leal zabaleta",\n"amount": -600.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * dividendos 133goau4",\n"amount": 17.29\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "compra inter cel inter pre 10gb mensal",\n"amount": -30.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "cashback inter pre 10gb mensal",\n"amount": 3.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado maria de lourdes dumith manso",\n"amount": -20.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado gicele rosa lazzari",\n"amount": -20.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * rendimento 50 xpca11",\n"amount": 2.00\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pagamento efetuado fatura cartão inter",\n"amount": -337.07\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * rendimento 135vghf11",\n"amount": 12.15\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * juros s/capital 38 bbas3",\n"amount": 15.61\n},\n{\n"month": "12",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pagamento efetuado cia estadual de dist",\n"amount": -152.30\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix recebido lucas da silva lazzari",\n"amount": 3200.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pagamento efetuado f souto imoveis ltda",\n"amount": -1802.17\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix recebido ampla visao informatica ltda",\n"amount": 3528.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pagamento efetuado aymore creditofinanciamento e investim",\n"amount": -770.26\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pagamento efetuado osirnet info telecom ltda",\n"amount": -110.13\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado kiwify pagamentos tecnologia e servicos ltda",\n"amount": -29.55\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "compra no débito marineiaelertdravmonte bonitobra",\n"amount": -4.80\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado silvia regina leal zabaleta",\n"amount": -800.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "pix enviado nicki samuel da silva chaves",\n"amount": -20.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * juros s/capital 35 brap3",\n"amount": 24.31\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * juros s/capital 30 petr4",\n"amount": 10.53\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "Banco do Brasil",\n"description": "crédito evento b3 * prov * dividendos 30 petr4",\n"amount": 3.41\n},\n{\n"month": "11 ...
#  '[\n{\n"month": "11",\n"year": 2024,\n"bank": "inter pre",\n"description": "compra inter cel",\n"amount": -30.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "inter pre",\n"description": "cashback",\n"amount": 3.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * rendimento 50 xpca11",\n"amount": 2.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * dividendos 80 sanb3",\n"amount": 2.04\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * juros s/capital 80 sanb3",\n"amount": 11.29\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * rendimento 135vghf11",\n"amount": 12.15\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "pix",\n"description": "neide iara da silva lazzari",\n"amount": 72.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado cia estadual de dist",\n"amount": -174.64\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado f souto imoveis ltda",\n"amount": -1793.27\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado osirnet info telecom ltda",\n"amount": -110.13\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "pix",\n"description": "lucas da silva lazzari",\n"amount": 3050.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado aymore creditofinanciamento e investim",\n"amount": -771.19\n},\n{\n"month": "11",\n"year": 2024,\n"bank": "pix",\n"description": "ampla visao informatica ltda",\n"amount": 1974.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pix enviado richeli da cruz mota",\n"amount": -15.00\n},\n{\n"month": "11",\n"year": 2024,\n"bank": null,\n"description": "pix recebido richeli da cruz mota",\n"amount": 5.00\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "inter pre",\n"description": "compra inter cel",\n"amount": -30.00\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "inter pre",\n"description": "cashback",\n"amount": 2.10\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * rendimento 40 xpca11",\n"amount": 3.40\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "pix",\n"description": "neide iara da silva lazzari",\n"amount": 245.00\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pix enviado lucas da silva lazzari",\n"amount": -150.00\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pix enviado lucas lopes porto 04333180074",\n"amount": -3.50\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "débito b3 liquidação b3 *07/10/2024",\n"amount": -193.24\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "B3",\n"description": "crédito evento b3 * prov * rendimento 120vghf11",\n"amount": 9.60\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado fatura cartão inter",\n"amount": -93.91\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado cia estadual de dist",\n"amount": -160.55\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado aymore creditofinanciamento e investim",\n"amount": -771.82\n},\n{\n"month": "10",\n"year": 2024,\n"bank": "pix",\n"description": "lucas da silva lazzari",\n"amount": 3050.00\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado f souto imoveis ltda",\n"amount": -1902.68\n},\n{\n"month": "10",\n"year": 2024,\n"bank": null,\n"description": "pagamento efetuado osirnet info telecom ltda",\n"amount": -110.13\n}\n]']

# %%
import json

cleaned_transactions = []
for batch in formatted_batches:
    cleaned_transactions.extend(json.loads(batch))

cleaned_transactions
# Out:
# [{'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * juros s/capital 38 bbas3',
#   'amount': 5.7},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * dividendos 30 petr4',
#   'amount': 46.55},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * dividendos 30 petr4',
#   'amount': 15.79},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado nicki samuel da silva chaves',
#   'amount': -16.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado silvia regina leal zabaleta',
#   'amount': -600.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * dividendos 133goau4',
#   'amount': 17.29},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'compra inter cel inter pre 10gb mensal',
#   'amount': -30.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'cashback inter pre 10gb mensal',
#   'amount': 3.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado maria de lourdes dumith manso',
#   'amount': -20.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado gicele rosa lazzari',
#   'amount': -20.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * rendimento 50 xpca11',
#   'amount': 2.0},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pagamento efetuado fatura cartão inter',
#   'amount': -337.07},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * rendimento 135vghf11',
#   'amount': 12.15},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * juros s/capital 38 bbas3',
#   'amount': 15.61},
#  {'month': '12',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pagamento efetuado cia estadual de dist',
#   'amount': -152.3},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix recebido lucas da silva lazzari',
#   'amount': 3200.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pagamento efetuado f souto imoveis ltda',
#   'amount': -1802.17},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix recebido ampla visao informatica ltda',
#   'amount': 3528.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pagamento efetuado aymore creditofinanciamento e investim',
#   'amount': -770.26},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pagamento efetuado osirnet info telecom ltda',
#   'amount': -110.13},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado kiwify pagamentos tecnologia e servicos ltda',
#   'amount': -29.55},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'compra no débito marineiaelertdravmonte bonitobra',
#   'amount': -4.8},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado silvia regina leal zabaleta',
#   'amount': -800.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado nicki samuel da silva chaves',
#   'amount': -20.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * juros s/capital 35 brap3',
#   'amount': 24.31},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * juros s/capital 30 petr4',
#   'amount': 10.53},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'crédito evento b3 * prov * dividendos 30 petr4',
#   'amount': 3.41},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'Banco do Brasil',
#   'description': 'pix enviado marcelo gomes lerm',
#   'amount': -16.25},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'inter pre',
#   'description': 'compra inter cel',
#   'amount': -30.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'inter pre',
#   'description': 'cashback',
#   'amount': 3.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * rendimento 50 xpca11',
#   'amount': 2.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * dividendos 80 sanb3',
#   'amount': 2.04},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * juros s/capital 80 sanb3',
#   'amount': 11.29},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * rendimento 135vghf11',
#   'amount': 12.15},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'pix',
#   'description': 'neide iara da silva lazzari',
#   'amount': 72.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado cia estadual de dist',
#   'amount': -174.64},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado f souto imoveis ltda',
#   'amount': -1793.27},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado osirnet info telecom ltda',
#   'amount': -110.13},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'pix',
#   'description': 'lucas da silva lazzari',
#   'amount': 3050.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado aymore creditofinanciamento e investim',
#   'amount': -771.19},
#  {'month': '11',
#   'year': 2024,
#   'bank': 'pix',
#   'description': 'ampla visao informatica ltda',
#   'amount': 1974.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pix enviado richeli da cruz mota',
#   'amount': -15.0},
#  {'month': '11',
#   'year': 2024,
#   'bank': None,
#   'description': 'pix recebido richeli da cruz mota',
#   'amount': 5.0},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'inter pre',
#   'description': 'compra inter cel',
#   'amount': -30.0},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'inter pre',
#   'description': 'cashback',
#   'amount': 2.1},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * rendimento 40 xpca11',
#   'amount': 3.4},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'pix',
#   'description': 'neide iara da silva lazzari',
#   'amount': 245.0},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pix enviado lucas da silva lazzari',
#   'amount': -150.0},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pix enviado lucas lopes porto 04333180074',
#   'amount': -3.5},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'débito b3 liquidação b3 *07/10/2024',
#   'amount': -193.24},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'B3',
#   'description': 'crédito evento b3 * prov * rendimento 120vghf11',
#   'amount': 9.6},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado fatura cartão inter',
#   'amount': -93.91},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado cia estadual de dist',
#   'amount': -160.55},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado aymore creditofinanciamento e investim',
#   'amount': -771.82},
#  {'month': '10',
#   'year': 2024,
#   'bank': 'pix',
#   'description': 'lucas da silva lazzari',
#   'amount': 3050.0},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado f souto imoveis ltda',
#   'amount': -1902.68},
#  {'month': '10',
#   'year': 2024,
#   'bank': None,
#   'description': 'pagamento efetuado osirnet info telecom ltda',
#   'amount': -110.13}]

# %%
transactions = Transactions(transactions=cleaned_transactions)
for transaction in transactions.transactions:
    transaction.bank = "Inter"

transactions
# Out:
# Transactions(transactions=[Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * juros s/capital 38 bbas3', amount=5.7), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * dividendos 30 petr4', amount=46.55), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * dividendos 30 petr4', amount=15.79), Transaction(year=2024, month=12, bank='Inter', description='pix enviado nicki samuel da silva chaves', amount=-16.0), Transaction(year=2024, month=12, bank='Inter', description='pix enviado silvia regina leal zabaleta', amount=-600.0), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * dividendos 133goau4', amount=17.29), Transaction(year=2024, month=12, bank='Inter', description='compra inter cel inter pre 10gb mensal', amount=-30.0), Transaction(year=2024, month=12, bank='Inter', description='cashback inter pre 10gb mensal', amount=3.0), Transaction(year=2024, month=12, bank='Inter', description='pix enviado maria de lourdes dumith manso', amount=-20.0), Transaction(year=2024, month=12, bank='Inter', description='pix enviado gicele rosa lazzari', amount=-20.0), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * rendimento 50 xpca11', amount=2.0), Transaction(year=2024, month=12, bank='Inter', description='pagamento efetuado fatura cartão inter', amount=-337.07), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * rendimento 135vghf11', amount=12.15), Transaction(year=2024, month=12, bank='Inter', description='crédito evento b3 * prov * juros s/capital 38 bbas3', amount=15.61), Transaction(year=2024, month=12, bank='Inter', description='pagamento efetuado cia estadual de dist', amount=-152.3), Transaction(year=2024, month=11, bank='Inter', description='pix recebido lucas da silva lazzari', amount=3200.0), Transaction(year=2024, month=11, bank='Inter', description='pagamento efetuado f souto imoveis ltda', amount=-1802.17), Transaction(year=2024, month=11, bank='Inter', description='pix recebido ampla visao informatica ltda', amount=3528.0), Transaction(year=2024, month=11, bank='Inter', description='pagamento efetuado aymore creditofinanciamento e investim', amount=-770.26), Transaction(year=2024, month=11, bank='Inter', description='pagamento efetuado osirnet info telecom ltda', amount=-110.13), Transaction(year=2024, month=11, bank='Inter', description='pix enviado kiwify pagamentos tecnologia e servicos ltda', amount=-29.55), Transaction(year=2024, month=11, bank='Inter', description='compra no débito marineiaelertdravmonte bonitobra', amount=-4.8), Transaction(year=2024, month=11, bank='Inter', description='pix enviado silvia regina leal zabaleta', amount=-800.0), Transaction(year=2024, month=11, bank='Inter', description='pix enviado nicki samuel da silva chaves', amount=-20.0), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * juros s/capital 35 brap3', amount=24.31), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * juros s/capital 30 petr4', amount=10.53), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * dividendos 30 petr4', amount=3.41), Transaction(year=2024, month=11, bank='Inter', description='pix enviado marcelo gomes lerm', amount=-16.25), Transaction(year=2024, month=11, bank='Inter', description='compra inter cel', amount=-30.0), Transaction(year=2024, month=11, bank='Inter', description='cashback', amount=3.0), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * rendimento 50 xpca11', amount=2.0), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * dividendos 80 sanb3', amount=2.04), Transaction(year=2024, month=11, bank='Inter', description='crédito evento b3 * prov * juros s/capital 80 sanb3', amount=11.29), Transaction(year=202 ...
